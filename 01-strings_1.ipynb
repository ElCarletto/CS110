# %% [markdown]
# <a href="https://colab.research.google.com/github/ElCarletto/CS110/blob/main/01-strings_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Strings

# %% [markdown]
# ### Basics

# %%
"this is a string that is also a sentence"
# Out:
# 'this is a string that is also a sentence'

# %%
'this'
# Out:
# 'this'

# %%
't'
# Out:
# 't'

# %%
'598798234792'
# Out:
# '598798234792'

# %%
'this is a string too '
# Out:
# 'this is a string too '

# %%
"""
put
things
on
multiple
lines
"""
# Out:
# '\nput \nthings\non \nmultiple \nlines\n'

# %% [markdown]
# ### `print`

# %%
'string 1'
'string 2'
'string 3'
# Out:
# 'string 3'

# %%
print('string 1')
print('string 2')
print('string 3')
# Out:
# string 1
# string 2
# string 3

# %% [markdown]
# ### Variables

# %%
word = "Microphone"

# %%
word = "Camera"

# %%
word
# Out:
# 'Camera'

# %%
in_snake_case = "this is another variable"

# %%
camelCase = 'Do as the romans do... so don\'t write camel case'

# %% [markdown]
# ### Interpolation

# %%
word = "Microphone"

# %%
f"My word is: {word}"
# Out:
# 'My word is: Microphone'

# %%
my_name = "Max"

# %%
f"Hi my name is {my_name}"
# Out:
# 'Hi my name is Max'

# %%
name = "Max"
colour = "Black"
country = "The United States"

f"Hi, my name is {name}, my favourite colour is {colour}, and I live in {country}"
# Out:
# 'Hi, my name is Max, my favourite colour is Black, and I live in The United States'

# %% [markdown]
# ## 👉 Please <font color='red'> **(ctrl-s or cmd-s)** save and "pin revision" </font>
# ## 👉 Rename the current pinned revision to "Section 1"

# %% [markdown]
# ### Challenge
#
# <div class='alert alert-info'>
#   🎒
#   Code a "story" about your name, age, and favourite TV show
# </div>
# <br/>
# <details>
# <summary><u>Solution</u></summary>
#
# ```python
# my_name = "Maggie"
# my_age = "∞"
# my_TV = "The Afterparty"
# print(f"Hi, I'm {my_name}, I'm {my_age} years-old, and I love \"{my_TV}\".")
# ```
#
# > Hi, I'm Maggie, I'm ∞ years-old, and I love "The Afterparty".
#
# <div class='alert alert-warning'>
#   ❌✍️ Just don't do this...
# </div>
#
# ```python
# myName = "pleaseDont"
# myAge = "thisIsCalledCamelCase"
# myTV = "python_uses_snake_case_99%_of_the_time"
# ```
#
# </details>

# %%
my_name = "Maggie"
my_age = "∞"
my_TV = "The Afterparty"
print(f"Hi, I'm {my_name}, I'm {my_age} years-old, and I love \"{my_TV}\".")
# Out:
# Hi, I'm Maggie, I'm ∞ years-old, and I love "The Afterparty".

# %% [markdown]
# ### String Methods

# %%
name
type(name)
# Out:
# str

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %% [markdown]
# <div class='alert alert-success'>
#   🔬🧵 Don't get overwhelmed, just look at a couple
# </div>

# %% [markdown]
# - `.upper`
# - `.lower`
# - `.strip`
# - `.endswith`
# - `.startswith`

# %%
full_name = "max humber"
full_name.title()
# Out:
# 'Max Humber'

# %%
"SALKJHK;DJHFLKAWEHFLKSDHFLFKJDS".lower()
# Out:
# 'salkjhk;djhflkawehflksdhflfkjds'

# %%
"       Lot's of padding.       ".strip()
# Out:
# "Lot's of padding."

# %%
"song_243.mp3".endswith(".flac")
# Out:
# False

# %% [markdown]
# ### `in`

# %%
"good" in "good bye"
# Out:
# True

# %%
"Good".lower() in "good bye"
# Out:
# True

# %% [markdown]
# ## 👉 Please <font color='red'> **(ctrl-s or cmd-s)** save and "pin revision" </font>
# ## 👉 Rename the current pinned revision to "Section 2"

# %% [markdown]
# ### Homework
#
# <div class='alert alert-info'>
#   🎒 Replace all of the punctuation in the following quotes
# </div>

# %%
quote_1 = "Oh I gotta get on that internet, I'm late on everything!"

# %%
quote_1 = quote_1.lower().replace(",", "").replace("!", "").replace("'", "")

# %%
quote_2 = "What’s the deal with lampshades? I mean if it’s a lamp, why do you want shade?"

# %%
quote_2.replace("?", "").replace("’", "").replace(",", "").lower()
# Out:
# 'whats the deal with lampshades i mean if its a lamp why do you want shade'

# %% [markdown]
# ## 👉 Please <font color='red'> **(ctrl-s or cmd-s)** save and "pin revision" </font>
# ## 👉 Rename the current pinned revision to "Section 3"
